# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import RMSprop
from keras.layers import LSTM, Dropout
from rbf_layer import RBFLayer, InitCentersRandom
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
def roll_beta(window_size, stock, market):
    data = {'X': market, 'Y': stock}
    df = pd.DataFrame(data)
    cov = df.X.rolling(window=window_size).cov(df.Y)
    var = df.X.rolling(window=window_size).var()
    roling_beta = cov/var
    return np.array(roling_beta[window_size - 1:])

# %%
def return_from_stock(stock_data):
    stock = pd.read_csv(f"{stock_data}")
    #creating new column 'return' it is percentage change between current and last month close price
    stock['return'] = stock.Zamkniecie.pct_change()
    return np.array(stock['return'][1:]) # first value is NaN so [1:]

# %%
wig_20_return = return_from_stock('wig20_m.csv')
peo_return = return_from_stock('pkn_m.csv')

# %%
peo_roll_beta = roll_beta(36, peo_return, wig_20_return)

# %%
peo_roll_beta
# Out:
# array([0.96741153, 0.96982935, 0.95011095, 1.09958231, 1.16862337,
#        1.13459742, 1.14194265, 1.15726181, 1.12772388, 1.1105736 ,
#        1.1138578 , 1.11862132, 1.13150836, 1.1375411 , 1.15180667,
#        1.10552502, 1.10656651, 1.10388783, 1.09376852, 1.10486779,
#        1.18194164, 1.11047588, 1.12713476, 1.16081385, 1.16559972,
#        1.16142674, 1.16779862, 1.17356173, 1.03089019, 0.93788915,
#        0.95953821, 0.95193808, 0.96810992, 0.94070256, 0.97530962,
#        0.93394606, 0.91898097, 0.90360467, 0.84726727, 0.82545087,
#        0.82364202, 0.84335704, 0.83348986, 0.8508626 , 0.86996876,
#        0.86519387, 0.90036765, 0.9063625 , 0.89846063, 0.88894647,
#        0.89602742, 0.90367105, 0.89294077, 0.89920867, 0.89124903,
#        0.89408428, 0.82643289, 0.82508134, 0.84532879, 0.85332806,
#        0.85220013, 0.82106729, 0.81454327, 0.83466455, 0.87022312,
#        0.89026959, 0.86823303, 0.91603475, 0.89090475, 0.93692833,
#        0.88917657, 0.98212532, 1.00791753, 1.06028297, 1.18413996,
#        1.20521767, 1.25141826, 1.26749761, 1.26817223, 1.25404773,
#        1.24494454, 1.23570504, 1.19113517, 1.20415768, 1.20591399,
#        1.21421995, 1.19719424, 1.19853741, 1.25469872, 1.20061775,
#        1.22989016, 1.27779781, 1.29014759, 1.3168392 , 1.27545753,
#        1.27014077, 1.27046471, 1.26987144, 1.27241572, 1.24624543,
#        1.31626396, 1.34209478, 1.3450339 , 1.19107929, 1.24873494,
#        1.2390318 , 1.26008306, 1.31209039, 1.24935788, 1.15440806,
#        1.10369364, 1.0984528 , 1.07515061, 1.06463368, 0.94801914,
#        0.94539465, 0.98580018, 0.99008131, 1.04591024, 1.05991394,
#        1.05601916, 0.98519034, 1.03992916, 1.04685797, 1.03792395,
#        1.29446517, 1.2711922 , 1.14439646, 0.99017803, 1.03049442,
#        1.02183697, 1.07086926, 1.10760933, 1.10712945, 1.01774782,
#        1.03467187, 1.03730941, 1.03345764, 1.13019204, 1.1658674 ,
#        1.13676813, 1.18583957, 1.23279742, 1.18664509, 1.22869111,
#        1.294159  , 1.35526371, 1.35934214, 1.31392965, 1.32594759,
#        1.51528328, 1.5375912 , 1.47391011, 1.47872688, 1.476443  ,
#        1.47453933, 1.49728596, 1.46381422, 1.39891647, 1.38855535,
#        1.43727718, 1.36264047, 1.38882171, 1.40144975, 1.54731619,
#        1.50884342, 1.2821424 , 1.24467049, 1.23994001, 1.21048638,
#        1.21796137, 1.17180882, 1.19556577, 1.20363123, 1.48184507,
#        1.44990396, 1.45779485, 1.44828304, 1.43989823, 1.42874463,
#        1.47579834, 1.48282582, 1.46769333, 1.44675818, 1.43240687,
#        1.42852508, 1.41380266, 1.41347389, 1.44130043, 1.36312153,
#        1.35225783, 1.24315594, 1.2501753 , 1.27241229, 1.298192  ,
#        1.32949752, 1.32155178, 1.24443856, 1.25375006, 1.24426884,
#        1.21379203, 1.16774842, 1.27358967, 1.25829665, 1.25381091])

# %%
# creating training dataset
df_data = pd.DataFrame({
    'target': peo_roll_beta,
    't-1': np.roll(peo_roll_beta, 1),
    't-2': np.roll(peo_roll_beta, 2),
    't-3': np.roll(peo_roll_beta, 3),
    't-4': np.roll(peo_roll_beta, 4),
    't-5': np.roll(peo_roll_beta, 5)
})

# %%
df_data = df_data.iloc[5:]
df_data
# Out:
#        target       t-1       t-2       t-3       t-4       t-5
# 5    1.134597  1.168623  1.099582  0.950111  0.969829  0.967412
# 6    1.141943  1.134597  1.168623  1.099582  0.950111  0.969829
# 7    1.157262  1.141943  1.134597  1.168623  1.099582  0.950111
# 8    1.127724  1.157262  1.141943  1.134597  1.168623  1.099582
# 9    1.110574  1.127724  1.157262  1.141943  1.134597  1.168623
# ..        ...       ...       ...       ...       ...       ...
# 200  1.213792  1.244269  1.253750  1.244439  1.321552  1.329498
# 201  1.167748  1.213792  1.244269  1.253750  1.244439  1.321552
# 202  1.273590  1.167748  1.213792  1.244269  1.253750  1.244439
# 203  1.258297  1.273590  1.167748  1.213792  1.244269  1.253750
# 204  1.253811  1.258297  1.273590  1.167748  1.213792  1.244269
#
# [200 rows x 6 columns]

# %%
X = df_data.iloc[:, -5:]
X
# Out:
#           t-1       t-2       t-3       t-4       t-5
# 5    1.168623  1.099582  0.950111  0.969829  0.967412
# 6    1.134597  1.168623  1.099582  0.950111  0.969829
# 7    1.141943  1.134597  1.168623  1.099582  0.950111
# 8    1.157262  1.141943  1.134597  1.168623  1.099582
# 9    1.127724  1.157262  1.141943  1.134597  1.168623
# ..        ...       ...       ...       ...       ...
# 200  1.244269  1.253750  1.244439  1.321552  1.329498
# 201  1.213792  1.244269  1.253750  1.244439  1.321552
# 202  1.167748  1.213792  1.244269  1.253750  1.244439
# 203  1.273590  1.167748  1.213792  1.244269  1.253750
# 204  1.258297  1.273590  1.167748  1.213792  1.244269
#
# [200 rows x 5 columns]

# %%
X = X[X.columns[::-1]]
X
# Out:
#           t-5       t-4       t-3       t-2       t-1
# 5    0.967412  0.969829  0.950111  1.099582  1.168623
# 6    0.969829  0.950111  1.099582  1.168623  1.134597
# 7    0.950111  1.099582  1.168623  1.134597  1.141943
# 8    1.099582  1.168623  1.134597  1.141943  1.157262
# 9    1.168623  1.134597  1.141943  1.157262  1.127724
# ..        ...       ...       ...       ...       ...
# 200  1.329498  1.321552  1.244439  1.253750  1.244269
# 201  1.321552  1.244439  1.253750  1.244269  1.213792
# 202  1.244439  1.253750  1.244269  1.213792  1.167748
# 203  1.253750  1.244269  1.213792  1.167748  1.273590
# 204  1.244269  1.213792  1.167748  1.273590  1.258297
#
# [200 rows x 5 columns]

# %%
y = df_data.target
y
# Out:
# 5      1.134597
# 6      1.141943
# 7      1.157262
# 8      1.127724
# 9      1.110574
#          ...
# 200    1.213792
# 201    1.167748
# 202    1.273590
# 203    1.258297
# 204    1.253811
# Name: target, Length: 200, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0, shuffle=False)

# %%
plt.plot(y)
plt.xlabel('Months')
plt.ylabel('Beta')
plt.title('Beta value (36 mounth) all data ')
# Out:
# Text(0.5, 1.0, 'Beta value (36 mounth) all data ')

# %%
y_test
# Out:
# 165    1.508843
# 166    1.282142
# 167    1.244670
# 168    1.239940
# 169    1.210486
# 170    1.217961
# 171    1.171809
# 172    1.195566
# 173    1.203631
# 174    1.481845
# 175    1.449904
# 176    1.457795
# 177    1.448283
# 178    1.439898
# 179    1.428745
# 180    1.475798
# 181    1.482826
# 182    1.467693
# 183    1.446758
# 184    1.432407
# 185    1.428525
# 186    1.413803
# 187    1.413474
# 188    1.441300
# 189    1.363122
# 190    1.352258
# 191    1.243156
# 192    1.250175
# 193    1.272412
# 194    1.298192
# 195    1.329498
# 196    1.321552
# 197    1.244439
# 198    1.253750
# 199    1.244269
# 200    1.213792
# 201    1.167748
# 202    1.273590
# 203    1.258297
# 204    1.253811
# Name: target, dtype: float64

# %%
def single_plot(y_pred, y_real, title):
    x = np.arange(1, len(y_pred) + 1)
    plt.plot(x,y_real, label='real')
    plt.plot(x,y_pred, label='predicted')
    plt.xlabel('day')
    plt.ylabel('month')
    plt.legend()
    plt.title(title)
    return plt.plot()

# %%
def generate_plots(y_pred_train, y_pred_test, y_train, y_test, title_1, title_2, to_png, png_name):
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))

    ax = axes[0]  # Wybór odpowiedniej osi
    plt.sca(ax)  # Ustawienie bieżącej osi
    single_plot(y_pred_train, y_train, title_1)

    ax = axes[1]  # Wybór odpowiedniej osi
    plt.sca(ax)  # Ustawienie bieżącej osi
    single_plot(y_pred_test, y_test, title_2)

    plt.tight_layout()
    if to_png:
        plt.savefig(f'{png_name}.png')
    plt.show()

# %% [markdown]
# ## Bulding RBF network model

# %%
model = Sequential()
rbflayer = RBFLayer(10,
                    initializer=InitCentersRandom(X_train),
                    betas=2.0,
                    input_shape=(5,))
model.add(rbflayer)
model.add(Dense(1))

model.compile(loss='mean_squared_error',
              optimizer=RMSprop())


model.fit(X_train, y_train,
          batch_size=10,
          epochs=200,
          verbose=1)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 1s 2ms/step - loss: 2.9883
# Epoch 2/200
# 16/16 [==============================] - 0s 1ms/step - loss: 2.3327
# Epoch 3/200
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8437
# Epoch 4/200
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4365
# Epoch 5/200
# 16/16 [==============================] - 0s 1ms/step - loss: 1.0968
# Epoch 6/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8143
# Epoch 7/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5862
# Epoch 8/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4113
# Epoch 9/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2831
# Epoch 10/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1940
# Epoch 11/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1378
# Epoch 12/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1048
# Epoch 13/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0866
# Epoch 14/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0744
# Epoch 15/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0636
# Epoch 16/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0543
# Epoch 17/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0464
# Epoch 18/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0390
# Epoch 19/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 20/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 21/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0222
# Epoch 22/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0181
# Epoch 23/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0148
# Epoch 24/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 25/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 26/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0086
# Epoch 27/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0074
# Epoch 28/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0068
# Epoch 29/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0063
# Epoch 30/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0059
# Epoch 31/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 32/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 33/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 34/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 35/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0046
# Epoch 36/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 37/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 38/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 39/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 40/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 41/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 42/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 43/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 44/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 45/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 46/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 47/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 48/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 49/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 50/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 51/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 52/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 53/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 54/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 55/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 56/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 57/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 58/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 59/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 60/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 61/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 62/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 63/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 64/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 65/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 66/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 67/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 68/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 69/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 70/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 71/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 72/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 73/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 74/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 75/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 76/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 77/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 78/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 79/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 80/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 81/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 82/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 83/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 84/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 85/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 86/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 87/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 88/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 89/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 90/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 91/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 92/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 93/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 94/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 95/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 96/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 97/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 98/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 99/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 100/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 101/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 102/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 103/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 104/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 105/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 106/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 107/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 108/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 109/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 110/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 111/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 112/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 113/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 114/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 115/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 116/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 117/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 118/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 119/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 120/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 121/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 122/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 123/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 124/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 125/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 126/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 127/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 128/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 129/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 130/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 131/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 132/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 133/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 134/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 135/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 136/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 137/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 138/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 139/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 140/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 141/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 142/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 143/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 144/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 145/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 146/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 147/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 148/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 149/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 150/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 151/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 152/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 153/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 154/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 155/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 156/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 157/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 158/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 159/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 160/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 161/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 162/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 163/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 164/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 165/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 166/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 167/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 168/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 169/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 170/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 171/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 172/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 173/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 174/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 175/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 176/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 177/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 178/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 179/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 180/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 181/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 182/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 183/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 184/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 185/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 186/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 187/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 188/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 189/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 190/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 191/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 192/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 193/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 194/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 195/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 196/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 197/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 198/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 199/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 200/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
generate_plots(y_pred_train, y_pred_test, y_train, y_test, 'Train data RBF network', 'Test data RBF network', True, 'RBF_pkn')
# Out:
# 5/5 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

def score_table(y_train, y_pred_train, y_test, y_pred_test, title):
    mse_train = mean_squared_error(y_train, y_pred_train)
    mae_train = mean_absolute_error(y_train, y_pred_train)
    r2_train = r2_score(y_train, y_pred_train)

    mse_test = mean_squared_error(y_test, y_pred_test)
    mae_test = mean_absolute_error(y_test, y_pred_test)
    r2_test = r2_score(y_test, y_pred_test)
    # Tworzenie tabeli
    data = {'data': ['train', 'test'],
            'MSE': [round(mse_train, 3), round(mse_test, 3)],
            'MAE': [round(mae_train, 3), round(mae_test, 3)],
            'R^2': [round(r2_train, 3), round(r2_test, 3)]
            }

    df = pd.DataFrame(data)

    # Tworzenie wykresu tabeli
    fig, ax = plt.subplots()  # Ustalenie rozmiaru wykresu
    ax.axis('off')  # Wyłączenie osi

    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')
    # Zapisywanie tabeli jako obraz PNG
    plt.savefig(f'tabela{title}.png', bbox_inches='tight', pad_inches=0.5)
    plt.show()

# %%
score_table(y_train, y_pred_train, y_test, y_pred_test, 'RBF_table_pkn')

# %% [markdown]
# ## Bulding XGBRegressor model

# %%
from xgboost import XGBRegressor
my_model = XGBRegressor(n_estimators=1000)
my_model.fit(X_train, y_train, verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
generate_plots(y_pred_train, y_pred_test, y_train, y_test, 'Train data XGB', 'Test data XGB', True, 'XGB_pkn')
score_table(y_train, y_pred_train, y_test, y_pred_test, 'XGB_table_pkn')
# Out:
# 5/5 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Bulding LSTM network

# %%
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 100)            40800
#
#  dropout (Dropout)           (None, 5, 100)            0
#
#  lstm_1 (LSTM)               (None, 5, 100)            80400
#
#  dropout_1 (Dropout)         (None, 5, 100)            0
#
#  lstm_2 (LSTM)               (None, 100)               80400
#
#  dense_1 (Dense)             (None, 25)                2525
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 204,151
# Trainable params: 204,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size= 1, epochs=20)
# Out:
# Epoch 1/20
# 160/160 [==============================] - 5s 5ms/step - loss: 0.0775
# Epoch 2/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0212
# Epoch 3/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0146
# Epoch 4/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0153
# Epoch 5/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0147
# Epoch 6/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0162
# Epoch 7/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0121
# Epoch 8/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0102
# Epoch 9/20
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0135
# Epoch 10/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0116
# Epoch 11/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0111
# Epoch 12/20
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0115
# Epoch 13/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0123
# Epoch 14/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0099
# Epoch 15/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0098
# Epoch 16/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0089
# Epoch 17/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0098
# Epoch 18/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0089
# Epoch 19/20
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0091
# Epoch 20/20
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0075

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
generate_plots(y_pred_train, y_pred_test, y_train, y_test, 'Train data LSTM network', 'Test data LSTM network ', True, 'LSTM_pkn')
score_table(y_train, y_pred_train, y_test, y_pred_test, 'LSTM_table_pkn')
# Out:
# 5/5 [==============================] - 2s 4ms/step
# 2/2 [==============================] - 1s 4ms/step

# %% [markdown]
# ## Bulding Linear regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
generate_plots(y_pred_train, y_pred_test, y_train, y_test, 'Train data LinearRegression', 'Test data LinearRegression', True, 'LinearRegression_pkn')
score_table(y_train, y_pred_train, y_test, y_pred_test, 'LinearRegression_table_pkn')
